# %% [markdown]
# # Project 1 Daniel Salicath

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt

# Importing packages

# %%
df = pd.read_csv('./daniel_test.csv')

# Importing dataset from excel

# %%
df.head(3)

# Looking at first 3 rows to see how the dataset is imported
# Out:
#    ANumber  SessionNumber                          Name  IDNumber Consent  \
# 0        1              1  ALBORNOZ VASCO MAICOL DUGLAS       NaN     NaN
# 1        1              2  ALBORNOZ VASCO MAICOL DUGLAS       NaN     NaN
# 2        1              3  ALBORNOZ VASCO MAICOL DUGLAS       NaN     NaN
#
#              Institucion  SessionDate   Age Gender1Female CellPhone1HaveCell  \
# 0  San Francisco de Asis    7222016.0  16.0            No                Yes
# 1  San Francisco de Asis    8052016.0  16.0            No                Yes
# 2  San Francisco de Asis    8192016.0  16.0            No                Yes
#
#         ...        MeanAchievedIndividual BaservbNotalottobeproudof  \
# 0       ...                           0.0                       3.0
# 1       ...                           0.0                       3.0
# 2       ...                           0.0                       3.0
#
#   BaservbIsometimesfeelIamgoodforn EndrvbEndDonthavealottobeproud  \
# 0                              3.0                            3.0
# 1                              3.0                            3.0
# 2                              3.0                            3.0
#
#   EndrvbEndIfeelgoodfornothing14 baseSelfEsteem EndSelfEsteem BaseRisk  \
# 0                            3.0           15.0          14.0      4.0
# 1                            3.0           15.0          14.0      4.0
# 2                            3.0           15.0          14.0      4.0
#
#   BaseavgSelfEsteem siblingsinschool
# 0               3.0              NaN
# 1               3.0              NaN
# 2               3.0              NaN
#
# [3 rows x 181 columns]

# %%
df.drop(['IDNumber', 'SessionNumber', 'Consent', 'SessionDate', 'CellPhone1HaveCell', 'HaveWhatsApp', 
           'FunctioningTV', 'FunctioningDVDPlayer', 'FunctioningWashingMachine', 'FunctioningRefrigerator', 'Moto',
           'Carro', 'Familyowndwelling', 'Internet', 'TravelTimetoSchool14', 'Modeoftravel', 'Job', 'Whatjob','DaysWorkedWeek', 'HoursWorkedDay', 'TimeforHomework',
          ], axis=1, inplace=True) 

# Deleting some variables not needed for this project

# %%
# Define a function to create the scatterplot. 

def scatterplot(x_data, y_data, x_label, y_label, title):

# Create the plot object
    _, ax = plt.subplots()

# Plot the data, set the size (s), color and transparency (alpha) of the points
    ax.scatter(x_data, y_data, s = 30, color = '#539caf', alpha = 0.75)

# Label the axes and provide a title
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)

# Call the function to create plot
scatterplot(x_data = df['GeneralRisk']
            , y_data = df['Minutesneededtowaitayearin']
            , x_label = 'General Risk'
            , y_label = 'Minutes'
            , title = 'Number of Minutes Needed to Wait One Year vs General Risk')
plt.show()

# We suspect that the question was not understood by subjects, using a scatter plot to look at the values

# %%
df.drop(['Minutesneededover20towait1', 'Minutesneededtowait6months', 'Minutesneededtowaitayearin',  
          ], axis=1, inplace=True) 

# Indeed there are big outliers (probably due to not understanding question)
# Made the right decision of not including these questions in endline survey
# Dropping the variables not understood by students

# %%
df.rename(columns={
        'GeneralRisk':'general_risk',
        'RatioFemale':'ratio_female_in_household',
    }, inplace=True)

# Renaming some variables. I keep the format for most, since I'm more familar with them

# %%
df.describe().T

# Transpose of describe command. Getting summary statistics of the dataset
# Out:
#                                    count        mean         std        min  \
# ANumber                           2904.0  182.363636  105.207935   1.000000
# Age                               2408.0   15.179402    1.156348  13.000000
# MealsMissed                       2408.0    0.694352    1.767434   0.000000
# MissSchoolInpast2weeks            2448.0    0.323529    0.467918   0.000000
# HowmanydaysMissedlasttwowe        2448.0    0.545752    0.935797   0.000000
# general_risk                      2440.0    6.881967    2.715271   1.000000
# RiskInSportsPhysicalAct           2440.0    7.373770    2.880362   1.000000
# RiskwithRegardtoHealthyActi       2416.0    3.748344    3.205003   1.000000
# RiskRidingMotoNoHelm              2408.0    2.215947    2.308175   1.000000
# NoInHousehold                     1624.0    4.862069    1.899688   2.000000
# ratio_female_in_household         1608.0    0.545618    0.207096   0.166667
# NoSchoolKids                      1616.0    2.133663    1.133538   1.000000
# NoInhouseholdworking              1616.0    1.742574    0.996872   0.000000
# ObjectiveSelected                 1114.0    3.460503    2.076429   1.000000
# EndCelular                        2152.0    0.754647    0.430396   0.000000
# EndWhatsApp                       1992.0    0.694779    0.460617   0.000000
# EndTV                             2152.0    0.962825    0.189234   0.000000
# EndInternet                       2048.0    0.781250    0.413500   0.000000
# EndMissMeals                      2152.0    0.189591    0.392069   0.000000
# EndMealsMissed07                  2144.0    0.548507    1.492078   0.000000
# EndPoor14                         2176.0    2.908088    0.324917   2.000000
# EndHoursStudy14                   2176.0    1.977941    0.706925   1.000000
# EndDifficultyofSchool15           2176.0    2.911765    0.680452   1.000000
# EndImpOfGrades15                  2168.0    4.575646    0.620223   2.000000
# EndParentsGrades15                2176.0    4.750000    0.565685   2.000000
# EndWorkwTeachers15                2176.0    3.492647    0.849038   1.000000
# EndRelationshipwTeachers15        2160.0    3.200000    0.787112   2.000000
# EndWorkwClassmates15              2160.0    3.448148    0.871076   1.000000
# EndGeneralRelationwClassmate      2152.0    3.535316    0.906435   1.000000
# EndImpofFinish9th15               2160.0    4.811111    0.452942   3.000000
# ...                                  ...         ...         ...        ...
# EndGenerallysatisfiedwithself     2144.0    3.358209    0.727083   1.000000
# EndIfeelgoodfornothing14          2160.0    2.181481    0.977955   1.000000
# EndParticipatedinCommunityact     2160.0    0.311111    0.463055   0.000000
# EndPreparedtotakeRisks110         2160.0    7.044444    2.377497   1.000000
# EndGamesSportsRiskiness110        2128.0    7.289474    2.512749   1.000000
# EndHealthRiskiness110             2104.0    4.015209    3.001308   1.000000
# EndWillingnesstoRidewithInto      2096.0    2.641221    2.533046   1.000000
# EndHowPatient16                   2112.0    3.515152    1.209373   1.000000
# End20Nowor251month0now1           2128.0    0.289474    0.453625   0.000000
# End20Nowor301month0now1           2120.0    0.441509    0.496684   0.000000
# End20Nowor256months0now           2096.0    0.179389    0.383770   0.000000
# End20Nowor306months0now           2112.0    0.223485    0.416679   0.000000
# End20Nowor251year0now1            2120.0    0.162264    0.368780   0.000000
# End20Nowor301year0now1            2120.0    0.154717    0.361720   0.000000
# TreatmentGroup                    2904.0    2.873278    1.403868   1.000000
# Treat2Dummy                       2904.0    0.217631    0.412706   0.000000
# Treat3Dummy                       2904.0    0.203857    0.402933   0.000000
# Treat4Dummy                       2904.0    0.181818    0.385761   0.000000
# Treat5Dummy                       2904.0    0.175620    0.380562   0.000000
# Achieved                          1102.0    0.578040    0.494096   0.000000
# MeanAchievedIndividual            2016.0    0.559987    0.326704   0.000000
# BaservbNotalottobeproudof         2408.0    2.807309    0.883442   1.000000
# BaservbIsometimesfeelIamgoodforn  2424.0    2.719472    0.892312   1.000000
# EndrvbEndDonthavealottobeproud    2144.0    3.014925    0.901992   1.000000
# EndrvbEndIfeelgoodfornothing14    2160.0    2.818519    0.977955   1.000000
# baseSelfEsteem                    2328.0   15.621993    2.305740   9.000000
# EndSelfEsteem                     2128.0   15.845865    2.579205   8.000000
# BaseRisk                          2360.0    5.047458    1.746878   1.000000
# BaseavgSelfEsteem                 2328.0    3.124399    0.461148   1.800000
# siblingsinschool                  1616.0    1.133663    1.133538   0.000000
#
#                                     25%    50%         75%    max
# ANumber                           91.00  182.0  274.000000  364.0
# Age                               14.00   15.0   16.000000   20.0
# MealsMissed                        0.00    0.0    0.000000    7.0
# MissSchoolInpast2weeks             0.00    0.0    1.000000    1.0
# HowmanydaysMissedlasttwowe         0.00    0.0    1.000000    5.0
# general_risk                       5.00    8.0    9.000000   10.0
# RiskInSportsPhysicalAct            5.00    8.0   10.000000   10.0
# RiskwithRegardtoHealthyActi        1.00    2.0    6.000000   10.0
# RiskRidingMotoNoHelm               1.00    1.0    2.000000   10.0
# NoInHousehold                      4.00    4.0    6.000000   11.0
# ratio_female_in_household          0.40    0.5    0.666667    1.0
# NoSchoolKids                       1.00    2.0    3.000000    6.0
# NoInhouseholdworking               1.00    2.0    2.000000    6.0
# ObjectiveSelected                  2.00    2.0    5.000000    8.0
# EndCelular                         1.00    1.0    1.000000    1.0
# EndWhatsApp                        0.00    1.0    1.000000    1.0
# EndTV                              1.00    1.0    1.000000    1.0
# EndInternet                        1.00    1.0    1.000000    1.0
# EndMissMeals                       0.00    0.0    0.000000    1.0
# EndMealsMissed07                   0.00    0.0    0.000000    7.0
# EndPoor14                          3.00    3.0    3.000000    4.0
# EndHoursStudy14                    2.00    2.0    2.000000    4.0
# EndDifficultyofSchool15            3.00    3.0    3.000000    5.0
# EndImpOfGrades15                   4.00    5.0    5.000000    5.0
# EndParentsGrades15                 5.00    5.0    5.000000    5.0
# EndWorkwTeachers15                 3.00    4.0    4.000000    5.0
# EndRelationshipwTeachers15         3.00    3.0    3.000000    5.0
# EndWorkwClassmates15               3.00    3.0    4.000000    5.0
# EndGeneralRelationwClassmate       3.00    3.0    4.000000    5.0
# EndImpofFinish9th15                5.00    5.0    5.000000    5.0
# ...                                 ...    ...         ...    ...
# EndGenerallysatisfiedwithself      3.00    3.0    4.000000    4.0
# EndIfeelgoodfornothing14           1.00    2.0    3.000000    4.0
# EndParticipatedinCommunityact      0.00    0.0    1.000000    1.0
# EndPreparedtotakeRisks110          5.00    8.0    9.000000   10.0
# EndGamesSportsRiskiness110         5.00    8.0    9.000000   10.0
# EndHealthRiskiness110              1.00    3.0    7.000000   10.0
# EndWillingnesstoRidewithInto       1.00    1.0    4.000000   10.0
# EndHowPatient16                    3.00    4.0    4.000000    6.0
# End20Nowor251month0now1            0.00    0.0    1.000000    1.0
# End20Nowor301month0now1            0.00    0.0    1.000000    1.0
# End20Nowor256months0now            0.00    0.0    0.000000    1.0
# End20Nowor306months0now            0.00    0.0    0.000000    1.0
# End20Nowor251year0now1             0.00    0.0    0.000000    1.0
# End20Nowor301year0now1             0.00    0.0    0.000000    1.0
# TreatmentGroup                     2.00    3.0    4.000000    5.0
# Treat2Dummy                        0.00    0.0    0.000000    1.0
# Treat3Dummy                        0.00    0.0    0.000000    1.0
# Treat4Dummy                        0.00    0.0    0.000000    1.0
# Treat5Dummy                        0.00    0.0    0.000000    1.0
# Achieved                           0.00    1.0    1.000000    1.0
# MeanAchievedIndividual             0.25    0.6    0.800000    1.0
# BaservbNotalottobeproudof          2.00    3.0    3.000000    4.0
# BaservbIsometimesfeelIamgoodforn   2.00    3.0    3.000000    4.0
# EndrvbEndDonthavealottobeproud     2.00    3.0    4.000000    4.0
# EndrvbEndIfeelgoodfornothing14     2.00    3.0    4.000000    4.0
# baseSelfEsteem                    14.00   16.0   17.000000   20.0
# EndSelfEsteem                     14.00   16.0   18.000000   20.0
# BaseRisk                           4.00    5.0    6.000000   10.0
# BaseavgSelfEsteem                  2.80    3.2    3.400000    4.0
# siblingsinschool                   0.00    1.0    2.000000    5.0
#
# [78 rows x 8 columns]

# %%
df.groupby(['TreatmentGroup','Gender1Female']).describe()

# Using the groupby command to look at summary statistics for different treatments and gender
# Out:
#                                        ANumber    Achieved         Age  \
# TreatmentGroup Gender1Female
# 1              No            count  304.000000    0.000000  304.000000
#                              mean   199.000000         NaN   15.083668
#                              std     64.091931         NaN    1.087173
#                              min    128.000000         NaN   13.000000
#                              25%    143.000000         NaN   14.000000
#                              50%    162.000000         NaN   15.000000
#                              75%    272.000000         NaN   16.000000
#                              max    294.000000         NaN   18.000000
#                Yes           count  304.000000    0.000000  304.000000
#                              mean   208.210526         NaN   14.846826
#                              std     66.239752         NaN    1.139053
#                              min    126.000000         NaN   14.000000
#                              25%    146.000000         NaN   14.000000
#                              50%    168.500000         NaN   14.000000
#                              75%    274.000000         NaN   16.000000
#                              max    293.000000         NaN   17.000000
# 2              No            count  232.000000  128.000000  232.000000
#                              mean   220.206897    0.273438   15.034483
#                              std    106.734085    0.447475    1.161661
#                              min     82.000000    0.000000   14.000000
#                              25%    104.000000    0.000000   14.000000
#                              50%    300.000000    0.000000   15.000000
#                              75%    317.000000    1.000000   16.000000
#                              max    329.000000    1.000000   17.000000
#                Yes           count  232.000000  132.000000  232.000000
#                              mean   196.482759    0.363636   15.551724
#                              std    102.473520    0.482878    1.479118
#                              min     86.000000    0.000000   14.000000
#                              25%    102.000000    0.000000   14.000000
#                              50%    122.000000    0.000000   15.000000
# ...                                        ...         ...         ...
# 4              No            std     92.531897    0.486352    1.189093
#                              min     43.000000    0.000000   14.000000
#                              25%     60.000000    0.000000   14.000000
#                              50%     72.000000    1.000000   15.000000
#                              75%    245.000000    1.000000   16.000000
#                              max    258.000000    1.000000   18.000000
#                Yes           count  208.000000  124.000000  208.000000
#                              mean   123.269231    0.846774   14.929977
#                              std     89.205428    0.361666    0.831847
#                              min     40.000000    0.000000   14.000000
#                              25%     49.000000    1.000000   14.000000
#                              50%     72.000000    1.000000   15.000000
#                              75%    238.000000    1.000000   15.179402
#                              max    255.000000    1.000000   17.000000
# 5              No            count  256.000000  131.000000  256.000000
#                              mean   201.937500    0.748092   15.599356
#                              std     18.139222    0.435775    1.319975
#                              min    170.000000    0.000000   14.000000
#                              25%    184.750000    0.500000   14.000000
#                              50%    204.000000    1.000000   15.589701
#                              75%    216.250000    1.000000   17.000000
#                              max    230.000000    1.000000   18.000000
#                Yes           count  184.000000  102.000000  184.000000
#                              mean   201.478261    0.803922   15.130435
#                              std     19.997529    0.398989    0.901940
#                              min    172.000000    0.000000   14.000000
#                              25%    186.000000    1.000000   14.000000
#                              50%    196.000000    1.000000   15.000000
#                              75%    221.000000    1.000000   16.000000
#                              max    234.000000    1.000000   17.000000
#
#                                       BaseRisk  BaseavgSelfEsteem  \
# TreatmentGroup Gender1Female
# 1              No            count  304.000000         304.000000
#                              mean     4.947368           3.073684
#                              std      1.772692           0.444213
#                              min      1.000000           1.800000
#                              25%      4.250000           2.800000
#                              50%      5.000000           3.000000
#                              75%      6.000000           3.400000
#                              max      8.750000           4.000000
#                Yes           count  304.000000         304.000000
#                              mean     4.766905           3.022337
#                              std      1.453954           0.422846
#                              min      1.000000           2.200000
#                              25%      4.000000           2.800000
#                              50%      4.750000           3.000000
#                              75%      5.250000           3.200000
#                              max     10.000000           3.800000
# 2              No            count  232.000000         232.000000
#                              mean     4.994652           3.270648
#                              std      1.431751           0.461381
#                              min      1.000000           2.000000
#                              25%      4.000000           3.124399
#                              50%      5.047458           3.400000
#                              75%      5.500000           3.600000
#                              max      8.000000           4.000000
#                Yes           count  232.000000         232.000000
#                              mean     4.811981           3.000000
#                              std      1.907852           0.455842
#                              min      1.750000           2.000000
#                              25%      3.500000           2.800000
#                              50%      4.750000           3.000000
# ...                                        ...                ...
# 4              No            std      1.326847           0.323054
#                              min      3.250000           2.800000
#                              25%      4.750000           3.000000
#                              50%      5.250000           3.200000
#                              75%      5.750000           3.600000
#                              max      9.250000           4.000000
#                Yes           count  208.000000         208.000000
#                              mean     4.482595           3.026831
#                              std      2.113146           0.434422
#                              min      1.000000           2.200000
#                              25%      3.000000           2.800000
#                              50%      4.750000           3.062199
#                              75%      6.250000           3.200000
#                              max      7.750000           3.800000
# 5              No            count  256.000000         256.000000
#                              mean     5.634296           3.351525
#                              std      1.470656           0.492030
#                              min      2.750000           1.800000
#                              25%      5.000000           3.093299
#                              50%      5.500000           3.400000
#                              75%      6.750000           3.800000
#                              max      8.750000           4.000000
#                Yes           count  184.000000         184.000000
#                              mean     5.086957           3.113043
#                              std      1.853381           0.525048
#                              min      1.000000           2.200000
#                              25%      3.500000           2.600000
#                              50%      5.250000           3.200000
#                              75%      6.500000           3.600000
#                              max      8.750000           3.800000
#
#                                     BaservbIsometimesfeelIamgoodforn  \
# TreatmentGroup Gender1Female
# 1              No            count                        304.000000
#                              mean                           2.552632
#                              std                            0.880965
#                              min                            1.000000
#                              25%                            2.000000
#                              50%                            2.500000
#                              75%                            3.000000
#                              max                            4.000000
#                Yes           count                        304.000000
#                              mean                           2.657895
#                              std                            0.898148
#                              min                            1.000000
#                              25%                            2.000000
#                              50%                            3.000000
#                              75%                            3.000000
#                              max                            4.000000
# 2              No            count                        232.000000
#                              mean                           2.965517
#                              std                            0.766518
#                              min                            2.000000
#                              25%                            2.000000
#                              50%                            3.000000
#                              75%                            4.000000
#                              max                            4.000000
#                Yes           count                        232.000000
#                              mean                           2.310345
#                              std                            0.876966
#                              min                            1.000000
#                              25%                            2.000000
#                              50%                            2.000000
# ...                                                              ...
# 4              No            std                            0.771589
#                              min                            2.000000
#                              25%                            2.000000
#                              50%                            3.000000
#                              75%                            4.000000
#                              max                            4.000000
#                Yes           count                        208.000000
#                              mean                           2.615385
#                              std                            0.837614
#                              min                            1.000000
#                              25%                            2.000000
#                              50%                            3.000000
#                              75%                            3.000000
#                              max                            4.000000
# 5              No            count                        256.000000
#                              mean                           3.125000
#                              std                            0.821285
#                              min                            2.000000
#                              25%                            2.000000
#                              50%                            3.000000
#                              75%                            4.000000
#                              max                            4.000000
#                Yes           count                        184.000000
#                              mean                           2.913043
#                              std                            1.020577
#                              min                            1.000000
#                              25%                            2.000000
#                              50%                            3.000000
#                              75%                            4.000000
#                              max                            4.000000
#
#                                     BaservbNotalottobeproudof   EH  \
# TreatmentGroup Gender1Female
# 1              No            count                 304.000000  0.0
#                              mean                    2.605263  NaN
#                              std                     0.813726  NaN
#                              min                     1.000000  NaN
#                              25%                     2.000000  NaN
#                              50%                     3.000000  NaN
#                              75%                     3.000000  NaN
#                              max                     4.000000  NaN
#                Yes           count                 296.000000  0.0
#                              mean                    3.054054  NaN
#                              std                     0.770505  NaN
#                              min                     2.000000  NaN
#                              25%                     2.000000  NaN
#                              50%                     3.000000  NaN
#                              75%                     4.000000  NaN
#                              max                     4.000000  NaN
# 2              No            count                 216.000000  0.0
#                              mean                    2.925926  NaN
#                              std                     0.980780  NaN
#                              min                     1.000000  NaN
#                              25%                     2.000000  NaN
#                              50%                     3.000000  NaN
#                              75%                     4.000000  NaN
#                              max                     4.000000  NaN
#                Yes           count                 232.000000  0.0
#                              mean                    2.655172  NaN
#                              std                     0.883749  NaN
#                              min                     1.000000  NaN
#                              25%                     2.000000  NaN
#                              50%                     3.000000  NaN
# ...                                                       ...  ...
# 4              No            std                     1.098249  NaN
#                              min                     1.000000  NaN
#                              25%                     2.000000  NaN
#                              50%                     2.000000  NaN
#                              75%                     4.000000  NaN
#                              max                     4.000000  NaN
#                Yes           count                 208.000000  0.0
#                              mean                    2.692308  NaN
#                              std                     0.868970  NaN
#                              min                     1.000000  NaN
#                              25%                     2.000000  NaN
#                              50%                     3.000000  NaN
#                              75%                     3.000000  NaN
#                              max                     4.000000  NaN
# 5              No            count                 248.000000  0.0
#                              mean                    3.129032  NaN
#                              std                     0.834167  NaN
#                              min                     1.000000  NaN
#                              25%                     3.000000  NaN
#                              50%                     3.000000  NaN
#                              75%                     4.000000  NaN
#                              max                     4.000000  NaN
#                Yes           count                 184.000000  0.0
#                              mean                    3.000000  NaN
#                              std                     0.782318  NaN
#                              min                     1.000000  NaN
#                              25%                     3.000000  NaN
#                              50%                     3.000000  NaN
#                              75%                     4.000000  NaN
#                              max                     4.000000  NaN
#
#                                     End20Nowor251month0now1  \
# TreatmentGroup Gender1Female
# 1              No            count               280.000000
#                              mean                  0.257143
#                              std                   0.437841
#                              min                   0.000000
#                              25%                   0.000000
#                              50%                   0.000000
#                              75%                   1.000000
#                              max                   1.000000
#                Yes           count               248.000000
#                              mean                  0.322581
#                              std                   0.468409
#                              min                   0.000000
#                              25%                   0.000000
#                              50%                   0.000000
#                              75%                   1.000000
#                              max                   1.000000
# 2              No            count               176.000000
#                              mean                  0.545455
#                              std                   0.499350
#                              min                   0.000000
#                              25%                   0.000000
#                              50%                   1.000000
#                              75%                   1.000000
#                              max                   1.000000
#                Yes           count               168.000000
#                              mean                  0.285714
#                              std                   0.453104
#                              min                   0.000000
#                              25%                   0.000000
#                              50%                   0.000000
# ...                                                     ...
# 4              No            std                   0.420266
#                              min                   0.000000
#                              25%                   0.000000
#                              50%                   0.000000
#                              75%                   0.000000
#                              max                   1.000000
#                Yes           count               192.000000
#                              mean                  0.208333
#                              std                   0.407178
#                              min                   0.000000
#                              25%                   0.000000
#                              50%                   0.000000
#                              75%                   0.000000
#                              max                   1.000000
# 5              No            count               192.000000
#                              mean                  0.333333
#                              std                   0.472637
#                              min                   0.000000
#                              25%                   0.000000
#                              50%                   0.000000
#                              75%                   1.000000
#                              max                   1.000000
#                Yes           count               120.000000
#                              mean                  0.266667
#                              std                   0.444071
#                              min                   0.000000
#                              25%                   0.000000
#                              50%                   0.000000
#                              75%                   1.000000
#                              max                   1.000000
#
#                                     End20Nowor251year0now1        ...         \
# TreatmentGroup Gender1Female                                      ...
# 1              No            count              280.000000        ...
#                              mean                 0.057143        ...
#                              std                  0.232531        ...
#                              min                  0.000000        ...
#                              25%                  0.000000        ...
#                              50%                  0.000000        ...
#                              75%                  0.000000        ...
#                              max                  1.000000        ...
#                Yes           count              240.000000        ...
#                              mean                 0.233333        ...
#                              std                  0.423836        ...
#                              min                  0.000000        ...
#                              25%                  0.000000        ...
#                              50%                  0.000000        ...
#                              75%                  0.000000        ...
#                              max                  1.000000        ...
# 2              No            count              176.000000        ...
#                              mean                 0.181818        ...
#                              std                  0.386795        ...
#                              min                  0.000000        ...
#                              25%                  0.000000        ...
#                              50%                  0.000000        ...
#                              75%                  0.000000        ...
#                              max                  1.000000        ...
#                Yes           count              168.000000        ...
#                              mean                 0.000000        ...
#                              std                  0.000000        ...
#                              min                  0.000000        ...
#                              25%                  0.000000        ...
#                              50%                  0.000000        ...
# ...                                                    ...        ...
# 4              No            std                  0.344153        ...
#                              min                  0.000000        ...
#                              25%                  0.000000        ...
#                              50%                  0.000000        ...
#                              75%                  0.000000        ...
#                              max                  1.000000        ...
#                Yes           count              192.000000        ...
#                              mean                 0.083333        ...
#                              std                  0.277108        ...
#                              min                  0.000000        ...
#                              25%                  0.000000        ...
#                              50%                  0.000000        ...
#                              75%                  0.000000        ...
#                              max                  1.000000        ...
# 5              No            count              192.000000        ...
#                              mean                 0.333333        ...
#                              std                  0.472637        ...
#                              min                  0.000000        ...
#                              25%                  0.000000        ...
#                              50%                  0.000000        ...
#                              75%                  1.000000        ...
#                              max                  1.000000        ...
#                Yes           count              128.000000        ...
#                              mean                 0.312500        ...
#                              std                  0.465334        ...
#                              min                  0.000000        ...
#                              25%                  0.000000        ...
#                              50%                  0.000000        ...
#                              75%                  1.000000        ...
#                              max                  1.000000        ...
#
#                                     RiskRidingMotoNoHelm  \
# TreatmentGroup Gender1Female
# 1              No            count            304.000000
#                              mean               1.868421
#                              std                1.767638
#                              min                1.000000
#                              25%                1.000000
#                              50%                1.000000
#                              75%                2.000000
#                              max               10.000000
#                Yes           count            288.000000
#                              mean               2.083333
#                              std                2.293758
#                              min                1.000000
#                              25%                1.000000
#                              50%                1.000000
#                              75%                1.250000
#                              max               10.000000
# 2              No            count            224.000000
#                              mean               1.535714
#                              std                0.983529
#                              min                1.000000
#                              25%                1.000000
#                              50%                1.000000
#                              75%                2.000000
#                              max                5.000000
#                Yes           count            232.000000
#                              mean               3.137931
#                              std                3.054757
#                              min                1.000000
#                              25%                1.000000
#                              50%                1.000000
# ...                                                  ...
# 4              No            std                2.320118
#                              min                1.000000
#                              25%                1.000000
#                              50%                1.000000
#                              75%                2.000000
#                              max               10.000000
#                Yes           count            208.000000
#                              mean               2.115385
#                              std                2.476197
#                              min                1.000000
#                              25%                1.000000
#                              50%                1.000000
#                              75%                1.000000
#                              max               10.000000
# 5              No            count            256.000000
#                              mean               2.968750
#                              std                2.608997
#                              min                1.000000
#                              25%                1.000000
#                              50%                1.500000
#                              75%                5.000000
#                              max                9.000000
#                Yes           count            184.000000
#                              mean               2.391304
#                              std                2.415598
#                              min                1.000000
#                              25%                1.000000
#                              50%                1.000000
#                              75%                3.000000
#                              max               10.000000
#
#                                     RiskwithRegardtoHealthyActi  Treat2Dummy  \
# TreatmentGroup Gender1Female
# 1              No            count                   304.000000        304.0
#                              mean                      3.947368          0.0
#                              std                       3.313717          0.0
#                              min                       1.000000          0.0
#                              25%                       1.000000          0.0
#                              50%                       2.500000          0.0
#                              75%                       7.000000          0.0
#                              max                      10.000000          0.0
#                Yes           count                   296.000000        304.0
#                              mean                      2.918919          0.0
#                              std                       2.501562          0.0
#                              min                       1.000000          0.0
#                              25%                       1.000000          0.0
#                              50%                       2.000000          0.0
#                              75%                       4.000000          0.0
#                              max                      10.000000          0.0
# 2              No            count                   232.000000        232.0
#                              mean                      3.034483          1.0
#                              std                       2.888793          0.0
#                              min                       1.000000          1.0
#                              25%                       1.000000          1.0
#                              50%                       1.000000          1.0
#                              75%                       4.000000          1.0
#                              max                      10.000000          1.0
#                Yes           count                   224.000000        232.0
#                              mean                      3.535714          1.0
#                              std                       3.024351          0.0
#                              min                       1.000000          1.0
#                              25%                       1.000000          1.0
#                              50%                       2.000000          1.0
# ...                                                         ...          ...
# 4              No            std                       3.291119          0.0
#                              min                       1.000000          0.0
#                              25%                       1.000000          0.0
#                              50%                       2.000000          0.0
#                              75%                       5.000000          0.0
#                              max                      10.000000          0.0
#                Yes           count                   200.000000        208.0
#                              mean                      3.560000          0.0
#                              std                       3.462128          0.0
#                              min                       1.000000          0.0
#                              25%                       1.000000          0.0
#                              50%                       1.000000          0.0
#                              75%                       7.000000          0.0
#                              max                      10.000000          0.0
# 5              No            count                   256.000000        256.0
#                              mean                      4.906250          0.0
#                              std                       3.240522          0.0
#                              min                       1.000000          0.0
#                              25%                       1.750000          0.0
#                              50%                       5.000000          0.0
#                              75%                       8.000000          0.0
#                              max                      10.000000          0.0
#                Yes           count                   184.000000        184.0
#                              mean                      3.521739          0.0
#                              std                       2.999010          0.0
#                              min                       1.000000          0.0
#                              25%                       1.000000          0.0
#                              50%                       2.000000          0.0
#                              75%                       5.000000          0.0
#                              max                      10.000000          0.0
#
#                                     Treat3Dummy  Treat4Dummy  Treat5Dummy  \
# TreatmentGroup Gender1Female
# 1              No            count        304.0        304.0        304.0
#                              mean           0.0          0.0          0.0
#                              std            0.0          0.0          0.0
#                              min            0.0          0.0          0.0
#                              25%            0.0          0.0          0.0
#                              50%            0.0          0.0          0.0
#                              75%            0.0          0.0          0.0
#                              max            0.0          0.0          0.0
#                Yes           count        304.0        304.0        304.0
#                              mean           0.0          0.0          0.0
#                              std            0.0          0.0          0.0
#                              min            0.0          0.0          0.0
#                              25%            0.0          0.0          0.0
#                              50%            0.0          0.0          0.0
#                              75%            0.0          0.0          0.0
#                              max            0.0          0.0          0.0
# 2              No            count        232.0        232.0        232.0
#                              mean           0.0          0.0          0.0
#                              std            0.0          0.0          0.0
#                              min            0.0          0.0          0.0
#                              25%            0.0          0.0          0.0
#                              50%            0.0          0.0          0.0
#                              75%            0.0          0.0          0.0
#                              max            0.0          0.0          0.0
#                Yes           count        232.0        232.0        232.0
#                              mean           0.0          0.0          0.0
#                              std            0.0          0.0          0.0
#                              min            0.0          0.0          0.0
#                              25%            0.0          0.0          0.0
#                              50%            0.0          0.0          0.0
# ...                                         ...          ...          ...
# 4              No            std            0.0          0.0          0.0
#                              min            0.0          1.0          0.0
#                              25%            0.0          1.0          0.0
#                              50%            0.0          1.0          0.0
#                              75%            0.0          1.0          0.0
#                              max            0.0          1.0          0.0
#                Yes           count        208.0        208.0        208.0
#                              mean           0.0          1.0          0.0
#                              std            0.0          0.0          0.0
#                              min            0.0          1.0          0.0
#                              25%            0.0          1.0          0.0
#                              50%            0.0          1.0          0.0
#                              75%            0.0          1.0          0.0
#                              max            0.0          1.0          0.0
# 5              No            count        256.0        256.0        256.0
#                              mean           0.0          0.0          1.0
#                              std            0.0          0.0          0.0
#                              min            0.0          0.0          1.0
#                              25%            0.0          0.0          1.0
#                              50%            0.0          0.0          1.0
#                              75%            0.0          0.0          1.0
#                              max            0.0          0.0          1.0
#                Yes           count        184.0        184.0        184.0
#                              mean           0.0          0.0          1.0
#                              std            0.0          0.0          0.0
#                              min            0.0          0.0          1.0
#                              25%            0.0          0.0          1.0
#                              50%            0.0          0.0          1.0
#                              75%            0.0          0.0          1.0
#                              max            0.0          0.0          1.0
#
#                                     baseSelfEsteem  general_risk  \
# TreatmentGroup Gender1Female
# 1              No            count      304.000000    304.000000
#                              mean        15.368421      6.763158
#                              std          2.221064      2.542670
#                              min          9.000000      1.000000
#                              25%         14.000000      5.000000
#                              50%         15.000000      7.500000
#                              75%         17.000000      9.000000
#                              max         20.000000     10.000000
#                Yes           count      288.000000    304.000000
#                              mean        15.083333      6.921053
#                              std          2.168832      2.770725
#                              min         11.000000      1.000000
#                              25%         13.750000      5.000000
#                              50%         15.000000      8.000000
#                              75%         16.000000     10.000000
#                              max         19.000000     10.000000
# 2              No            count      216.000000    232.000000
#                              mean        16.407407      6.965517
#                              std          2.382248      2.702992
#                              min         10.000000      1.000000
#                              25%         15.000000      5.000000
#                              50%         17.000000      8.000000
#                              75%         18.000000     10.000000
#                              max         20.000000     10.000000
#                Yes           count      232.000000    232.000000
#                              mean        15.000000      6.965517
#                              std          2.279212      2.638152
#                              min         10.000000      1.000000
#                              25%         14.000000      5.000000
#                              50%         15.000000      8.000000
# ...                                            ...           ...
# 4              No            std          1.666822      2.175739
#                              min         14.000000      1.000000
#                              25%         15.000000      6.000000
#                              50%         16.000000      7.000000
#                              75%         18.000000      9.000000
#                              max         20.000000     10.000000
#                Yes           count      176.000000    208.000000
#                              mean        15.045455      6.153846
#                              std          2.351457      3.016122
#                              min         11.000000      1.000000
#                              25%         13.000000      3.000000
#                              50%         15.000000      7.500000
#                              75%         17.000000      8.000000
#                              max         19.000000     10.000000
# 5              No            count      240.000000    248.000000
#                              mean        16.833333      6.903226
#                              std          2.522977      2.709764
#                              min          9.000000      1.000000
#                              25%         15.000000      5.000000
#                              50%         17.000000      8.000000
#                              75%         19.000000     10.000000
#                              max         20.000000     10.000000
#                Yes           count      184.000000    184.000000
#                              mean        15.565217      7.260870
#                              std          2.625243      2.989488
#                              min         11.000000      1.000000
#                              25%         13.000000      5.000000
#                              50%         16.000000      8.000000
#                              75%         18.000000     10.000000
#                              max         19.000000     10.000000
#
#                                     ratio_female_in_household  \
# TreatmentGroup Gender1Female
# 1              No            count                 216.000000
#                              mean                    0.442108
#                              std                     0.135976
#                              min                     0.200000
#                              25%                     0.333333
#                              50%                     0.428571
#                              75%                     0.500000
#                              max                     0.666667
#                Yes           count                 272.000000
#                              mean                    0.664216
#                              std                     0.185692
#                              min                     0.400000
#                              25%                     0.500000
#                              50%                     0.666667
#                              75%                     0.750000
#                              max                     1.000000
# 2              No            count                 136.000000
#                              mean                    0.431201
#                              std                     0.180069
#                              min                     0.166667
#                              25%                     0.250000
#                              50%                     0.400000
#                              75%                     0.625000
#                              max                     0.666667
#                Yes           count                 144.000000
#                              mean                    0.620326
#                              std                     0.121393
#                              min                     0.400000
#                              25%                     0.500000
#                              50%                     0.633333
# ...                                                       ...
# 4              No            std                     0.126964
#                              min                     0.200000
#                              25%                     0.250000
#                              50%                     0.333333
#                              75%                     0.400000
#                              max                     0.625000
#                Yes           count                 144.000000
#                              mean                    0.644290
#                              std                     0.191439
#                              min                     0.250000
#                              25%                     0.500000
#                              50%                     0.612500
#                              75%                     0.800000
#                              max                     1.000000
# 5              No            count                  80.000000
#                              mean                    0.451905
#                              std                     0.156260
#                              min                     0.250000
#                              25%                     0.333333
#                              50%                     0.450000
#                              75%                     0.500000
#                              max                     0.750000
#                Yes           count                  40.000000
#                              mean                    0.532857
#                              std                     0.158855
#                              min                     0.250000
#                              25%                     0.500000
#                              50%                     0.600000
#                              75%                     0.600000
#                              max                     0.714286
#
#                                     siblingsinschool
# TreatmentGroup Gender1Female
# 1              No            count        216.000000
#                              mean           1.148148
#                              std            1.081040
#                              min            0.000000
#                              25%            0.000000
#                              50%            1.000000
#                              75%            2.000000
#                              max            5.000000
#                Yes           count        272.000000
#                              mean           1.147059
#                              std            1.168652
#                              min            0.000000
#                              25%            0.000000
#                              50%            1.000000
#                              75%            2.000000
#                              max            5.000000
# 2              No            count        136.000000
#                              mean           1.235294
#                              std            1.399658
#                              min            0.000000
#                              25%            0.000000
#                              50%            1.000000
#                              75%            2.000000
#                              max            5.000000
#                Yes           count        144.000000
#                              mean           1.055556
#                              std            1.082459
#                              min            0.000000
#                              25%            0.000000
#                              50%            1.000000
# ...                                              ...
# 4              No            std            1.202032
#                              min            0.000000
#                              25%            0.000000
#                              50%            1.000000
#                              75%            1.000000
#                              max            4.000000
#                Yes           count        144.000000
#                              mean           1.055556
#                              std            0.973623
#                              min            0.000000
#                              25%            0.000000
#                              50%            1.000000
#                              75%            1.000000
#                              max            4.000000
# 5              No            count         80.000000
#                              mean           1.400000
#                              std            1.365024
#                              min            0.000000
#                              25%            0.000000
#                              50%            1.500000
#                              75%            2.000000
#                              max            4.000000
#                Yes           count         40.000000
#                              mean           2.400000
#                              std            0.810191
#                              min            1.000000
#                              25%            2.000000
#                              50%            3.000000
#                              75%            3.000000
#                              max            3.000000
#
# [80 rows x 77 columns]

# %%
df.Age = df.Age.fillna(np.mean(df.Age))
df.BaseavgSelfEsteem = df.BaseavgSelfEsteem.fillna(np.mean(df.BaseavgSelfEsteem))
df.BaseRisk = df.BaseRisk.fillna(np.mean(df.BaseRisk))

# Replacing missing values with the mean for variables needed later

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.gca()
# Creating figure

sns.boxplot(df.Age, orient='v',
            fliersize=6, linewidth=3, notch=True, 
            saturation=0.8, ax=ax)
# Setting up boxplot using seaborn

ax.set_ylabel('Age\n', fontsize=14)
ax.set_title('Statistic for proportion of the age of students\n', fontsize=18)
# Setting title and label y-axis

plt.show()

# Checking for outliers by looking at the age of students. 
# We can see that there is only one outlier, a 20 year old in 9th grade

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.gca()

sns.boxplot(df.BaseRisk, orient='v',
            fliersize=6, linewidth=3, notch=True, 
            saturation=0.8, ax=ax)

ax.set_ylabel('Risk\n', fontsize=14)
ax.set_title('Statistic for proportion of the risk level of students\n', fontsize=18)

plt.show()

# Same setup to look at how students answered risk questions by looking at BaseRisk (Average of risk questions)
# There are some students that say they are completely risk averse and some say not at all

# %%
def histogram_plotter(title, data1, data2):
    sns.set(rc={"figure.figsize": (10, 7)})
    sns.set_style('white')
# data1 input
    dist = sns.distplot(data1, hist_kws={'alpha':0.2}, kde_kws={'linewidth':5})
    
    dist.axvline(np.mean(data1), lw=5, c='darkred', ls='dashed')
    average_roll = '{0:.2f}'.format(np.mean(data1))
    title = 'Distribution of ' + title + '; average = '  + average_roll + '\n'
    dist.set_title(title, fontsize=16)
    dist = sns.distplot(data1, hist_kws={'alpha':0.2}, kde_kws={'linewidth':5})
    
# data2 input
    dist = sns.distplot(data2, hist_kws={'alpha':0.2}, kde_kws={'linewidth':5})
    
    dist.axvline(np.mean(data2), lw=5, c='darkblue', ls='dashed')
    average_roll = '{0:.2f}'.format(np.mean(data2))
    title = '' + title + '; average = '  + average_roll + '\n'
    dist.set_title(title, fontsize=16)
    dist = sns.distplot(data2, hist_kws={'alpha':0.2}, kde_kws={'linewidth':5})
    
# Creating function to do a histogram plotter for two variables

# %%
histogram_plotter('Age between Control Group and Treatment 4', df.Age[df.TreatmentGroup == 1], df.Age[df.TreatmentGroup == 4])
plt.show()

# Balance check between treatment groups for age
# In this case control group and treatment 4
# Tried with different treatments and they are balanced as well

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.gca()
sns.heatmap(df[['Age', 'NoInHousehold', 'ratio_female_in_household', 'siblingsinschool', 'EconomicCondition14', 'BaseavgSelfEsteem', 'BaseRisk', 'MeanAchievedIndividual', 'TreatmentGroup']].corr(), ax=ax)
plt.show()

# Using seaborns heatmap to look at the correlation between variables from my summary statistics table
# The map makes sense by showing that the Mean Achieved Objective is correlated with being in the later Treatment Groups (incentive)
# We can also notice how having more people in the household is highly correlated with having siblings in school
# This is what one would expect from these variables

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.gca()

sns.heatmap(df[['MeanAchievedIndividual','Treat2Dummy','Treat3Dummy', 'Treat4Dummy', 'Treat5Dummy']].corr(), ax=ax)
plt.show()

# Are the different treatments correlated with eachother? 
# Heatmap shows how the different goal-setting treatments are not correlated
# Here we can see that the two incentive treatments are correlated with achiving a goal

# %%
func_tuples = [('MeanAchievedIndividual', np.mean), ('Variance', np.var), ('Std', np.std)]
df.groupby(['Gender1Female'])[['Age']].agg(func_tuples).reset_index()

# How is age for different gender in our sample?
# Using numpy to look at the mean, variance and std
# Then I use the groupby command to create a table with these values
# This is the first step to make a better table
# Out:
#   Gender1Female                    Age
#                 MeanAchievedIndividual  Variance       Std
# 0            No              15.309992  1.392613  1.180090
# 1           Yes              15.043588  1.199744  1.095328

# %%
df.groupby(['TreatmentGroup','Gender1Female']).count()

# Counting observations for different treatments and gender
# Out:
#                               ANumber  Name  Institucion  Age  MissMeals  \
# TreatmentGroup Gender1Female
# 1              No                 304   304          304  304        304
#                Yes                304   304          304  304        296
# 2              No                 232   232          232  232        232
#                Yes                232   232          232  232        232
# 3              No                 224   224          224  224        224
#                Yes                272   272          272  272        272
# 4              No                 232   232          232  232        232
#                Yes                208   208          208  208        208
# 5              No                 256   256          256  256        256
#                Yes                184   184          184  184        184
#
#                               MealsMissed  DecisionMaker  EconomicCondition14  \
# TreatmentGroup Gender1Female
# 1              No                     304            304                  296
#                Yes                    296            304                  304
# 2              No                     232            232                  224
#                Yes                    216            232                  232
# 3              No                     216            224                  224
#                Yes                    272            272                  264
# 4              No                     232            232                  232
#                Yes                    200            208                  208
# 5              No                     256            256                  256
#                Yes                    184            184                  184
#
#                               MissSchoolInpast2weeks  \
# TreatmentGroup Gender1Female
# 1              No                                304
#                Yes                               304
# 2              No                                232
#                Yes                               232
# 3              No                                224
#                Yes                               272
# 4              No                                232
#                Yes                               208
# 5              No                                256
#                Yes                               184
#
#                               HowmanydaysMissedlasttwowe        ...         \
# TreatmentGroup Gender1Female                                    ...
# 1              No                                    304        ...
#                Yes                                   304        ...
# 2              No                                    232        ...
#                Yes                                   232        ...
# 3              No                                    224        ...
#                Yes                                   272        ...
# 4              No                                    232        ...
#                Yes                                   208        ...
# 5              No                                    256        ...
#                Yes                                   184        ...
#
#                               MeanAchievedIndividual  \
# TreatmentGroup Gender1Female
# 1              No                                  0
#                Yes                                 0
# 2              No                                232
#                Yes                               232
# 3              No                                224
#                Yes                               272
# 4              No                                232
#                Yes                               208
# 5              No                                256
#                Yes                               184
#
#                               BaservbNotalottobeproudof  \
# TreatmentGroup Gender1Female
# 1              No                                   304
#                Yes                                  296
# 2              No                                   216
#                Yes                                  232
# 3              No                                   224
#                Yes                                  264
# 4              No                                   232
#                Yes                                  208
# 5              No                                   248
#                Yes                                  184
#
#                               BaservbIsometimesfeelIamgoodforn  \
# TreatmentGroup Gender1Female
# 1              No                                          304
#                Yes                                         304
# 2              No                                          232
#                Yes                                         232
# 3              No                                          216
#                Yes                                         272
# 4              No                                          216
#                Yes                                         208
# 5              No                                          256
#                Yes                                         184
#
#                               EndrvbEndDonthavealottobeproud  \
# TreatmentGroup Gender1Female
# 1              No                                        272
#                Yes                                       256
# 2              No                                        176
#                Yes                                       160
# 3              No                                        200
#                Yes                                       232
# 4              No                                        176
#                Yes                                       192
# 5              No                                        192
#                Yes                                       128
#
#                               EndrvbEndIfeelgoodfornothing14  baseSelfEsteem  \
# TreatmentGroup Gender1Female
# 1              No                                        272             304
#                Yes                                       256             288
# 2              No                                        176             216
#                Yes                                       168             232
# 3              No                                        200             216
#                Yes                                       240             256
# 4              No                                        176             216
#                Yes                                       192             176
# 5              No                                        192             240
#                Yes                                       128             184
#
#                               EndSelfEsteem  BaseRisk  BaseavgSelfEsteem  \
# TreatmentGroup Gender1Female
# 1              No                       272       304                304
#                Yes                      256       304                304
# 2              No                       176       232                232
#                Yes                      160       232                232
# 3              No                       192       224                224
#                Yes                      232       272                272
# 4              No                       168       232                232
#                Yes                      192       208                208
# 5              No                       192       256                256
#                Yes                      128       184                184
#
#                               siblingsinschool
# TreatmentGroup Gender1Female
# 1              No                          216
#                Yes                         272
# 2              No                          136
#                Yes                         144
# 3              No                          160
#                Yes                         240
# 4              No                          128
#                Yes                         144
# 5              No                           80
#                Yes                          40
#
# [10 rows x 155 columns]

# %%
func_tuples = [('Mean', np.mean), ('Var', np.var), ('Std', np.std)]
df_sub_2 = df.groupby( ['TreatmentGroup','Gender1Female'] )[ ['Age', 'MeanAchievedIndividual'] ].agg(func_tuples).reset_index()
df_sub_2

# Now we can create a 'new' dataset (df_sub_2) to look at mean, var and std for both Treatment groups and gender
# Using numpy and groupby again
# Age seems balanced across treatments and gender
# We can see that treatment group 1 has no goal-setting (control group) and must be excluded in future graphs
# The mean of individual achieved objective clearly varies across treatments
# Out:
#   TreatmentGroup Gender1Female        Age                      \
#                                      Mean       Var       Std
# 0              1            No  15.083668  1.181945  1.087173
# 1              1           Yes  14.846826  1.297442  1.139053
# 2              2            No  15.034483  1.349455  1.161661
# 3              2           Yes  15.551724  2.187789  1.479118
# 4              3            No  15.500000  1.040359  1.019980
# 5              3           Yes  14.858218  0.600700  0.775048
# 6              4            No  15.379310  1.413942  1.189093
# 7              4           Yes  14.929977  0.691969  0.831847
# 8              5            No  15.599356  1.742334  1.319975
# 9              5           Yes  15.130435  0.813495  0.901940
#
#   MeanAchievedIndividual
#                     Mean       Var       Std
# 0                    NaN       NaN       NaN
# 1                    NaN       NaN       NaN
# 2               0.270115  0.059921  0.244787
# 3               0.357471  0.049477  0.222435
# 4               0.389881  0.083435  0.288851
# 5               0.574020  0.079839  0.282558
# 6               0.610920  0.082891  0.287909
# 7               0.833974  0.055276  0.235109
# 8               0.765625  0.052008  0.228052
# 9               0.747826  0.085788  0.292895

# %%
mean_total_co_day = df[df['TreatmentGroup']!=1].groupby(['TreatmentGroup','Gender1Female'])['MeanAchievedIndividual'].agg([np.mean, np.std]).reset_index()
mean_total_co_day

# We have the mean and std of achieved goal by treatment group and gender
# Out:
#    TreatmentGroup Gender1Female      mean       std
# 0               2            No  0.270115  0.244787
# 1               2           Yes  0.357471  0.222435
# 2               3            No  0.389881  0.288851
# 3               3           Yes  0.574020  0.282558
# 4               4            No  0.610920  0.287909
# 5               4           Yes  0.833974  0.235109
# 6               5            No  0.765625  0.228052
# 7               5           Yes  0.747826  0.292895

# %%
mean_total_co_day.TreatmentGroup.values

# Different treatment values in table above
# Out:
# array([2, 2, 3, 3, 4, 4, 5, 5])

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
df[df['TreatmentGroup']!=1].groupby(['TreatmentGroup','Gender1Female'])['MeanAchievedIndividual'].mean().unstack().plot(kind="bar"
                                                        ,colors=['darkred', 'steelblue'],
                                                          ax=ax)                                  
# Again excluding the control group, and looking at the mean of achieved objectives 
# Grouping by treatment group and gender

plt.xlabel("Treatment", fontsize=14)
plt.ylabel("Mean of Achievements", fontsize=14)
plt.xticks([0, 1, 2, 3], ["No SHG, No Prize", "SHG, No Prize", "No SHG, Prize",'SHG, Prize'])
plt.title('Achievement of Chosen Goal by Treatment\n', fontsize=16)
ax.legend(['Male', 'Female'])
# Title and labeling 

plt.show()

# Using the groupby to create a bar plot for different treatments and gender

# %%
# Calculate the mean and standard deviation for number of achieved goals by treatment group and gender

mean_total_co_day = df[df['TreatmentGroup']!=1].groupby(['TreatmentGroup','Gender1Female'])['MeanAchievedIndividual'].agg([np.mean, np.std]).reset_index()

# Define a function for a bar plot
def barplot(x_data, y_data, error_data, x_label, y_label, title):
    _, ax = plt.subplots()
# Draw bars, position them in the center of the tick mark on the x-axis
    ax.bar(x_data, y_data, color = '#537caf', align = 'center')
    
# Draw error bars to show standard deviation, set ls to 'none'
# to remove line between points
    ax.errorbar(x_data, y_data, yerr = error_data, color = '#297050', ls = 'none', lw = 2, capthick = 2)
    ax.set_ylabel(y_label)
    ax.set_xlabel(x_label)
    ax.set_title(title)

# Call the function to create a bar plot
barplot(x_data = mean_total_co_day[mean_total_co_day['Gender1Female']=='Yes'].TreatmentGroup.values
        , y_data = mean_total_co_day[mean_total_co_day['Gender1Female']=='Yes']['mean']
        , error_data = mean_total_co_day[mean_total_co_day['Gender1Female']=='Yes']['std']
        , x_label = 'Treatment Group'
        , y_label = 'Mean Achievement'
        , title = 'Mean Achievement for Females with Standard Deviation bars')

plt.xticks([2, 3, 4, 5], ["No SHG, No Prize", "SHG, No Prize", "No SHG, Prize",'SHG, Prize'])
plt.show()

# This figure shows the standard deviation for females in different treatment groups
# We can do the same with males by changing 'Yes' to 'No' in the code above

# %%
# Using seaborn barplot
sns.set_style("whitegrid")
tips = df
ax = sns.barplot(x="TreatmentGroup", y="MeanAchievedIndividual", hue="Gender1Female", data=tips, capsize=.1)

# Title and labeling 
ax.legend(loc = 'upper left', title = 'Female')
plt.xlabel("Treatment", fontsize=14)
plt.ylabel("Mean of Achievements", fontsize=14)
plt.xticks([1, 2, 3, 4], ["No SHG, No Prize", "SHG, No Prize", "No SHG, Prize",'SHG, Prize'])
plt.title('Achievement of Chosen Goal by Treatment\n', fontsize=16)
plt.xlim(0.5,4.5)

plt.show()

# Seaborn barplot give us error bars when looking at the difference between treatment groups and gender

# %%
# Using seaborn swarmplot
sns.swarmplot(x="TreatmentGroup", y="MeanAchievedIndividual", hue="Gender1Female", data=df)

plt.xlim(0.5,4.5)
plt.xlabel("Treatment", fontsize=14)
plt.ylabel("Mean of Achievements", fontsize=14)
plt.xticks([1, 2, 3, 4], ["No SHG, No Prize", "SHG, No Prize", "No SHG, Prize",'SHG, Prize'])
plt.title('Achievement of Chosen Goal by Treatment\n', fontsize=16)
# Labeling and making a title
plt.show()

# Using a swarmplot to get a different perspective on how gender played a role within 
# the different treatments on mean goal achievement
# This enables us to see that the student that didn't achieve any objectives in treatment 4 were all girls,
# in the other treatment the boys have more students not achieving any goals
# In the SHG treatment, only girls managed to achieve all their goals

# %%
g = sns.FacetGrid(df, col="TreatmentGroup")  
g.map(sns.distplot, "BaseRisk")
plt.show()

# Looking at the distribution of risk level across different treatment groups using seaborns distplot

# %%
sns.jointplot("MeanAchievedIndividual", "BaseavgSelfEsteem", data=df, kind='kde') 
plt.show()

# Looking at the distribution of self-esteem related to goal achievement

# %%
g = sns.JointGrid(x="BaseavgSelfEsteem", y="MeanAchievedIndividual", data=df)  
g.plot_joint(sns.regplot, order=2)  
g.plot_marginals(sns.distplot)  
plt.show()

# Using the regplot command, 
# we can see that students with higher self-esteem seem to have a higher mean of achieved objectives

# %%
# Difficulty level of goal on goal achievement, risk and self-esteem
# Using regplot, residplot and histogram
g = sns.PairGrid(df[["MeanAchievedIndividual", "BaseavgSelfEsteem", 'BaseRisk', "DiffofSel"]], hue="DiffofSel")  
g.map_upper(sns.regplot)  
g.map_lower(sns.residplot)  
g.map_diag(plt.hist)
for ax in g.axes.flat:  
    plt.setp(ax.get_xticklabels(), rotation=45)
g.add_legend()  
g.set(alpha=0.5) 

plt.show()

# Creating multiple tables to look at how the difficulty level a student give for their objective 
# might be correlated with their self-esteem, risk level and the mean achievement of the student
# We can see in the upper right corner, that picking goals with difficulty level 'Hard' seem to be correlated
# with stating a high risk level and achiving more goals. This is consistent with goal-setting theory
# We see the opposite for self-esteem, where high self-esteem picks easier goals and achieve them more often

# %% [markdown]
# # Report on 5 interesting things about my data

# %% [markdown]
# 1) Balance check for age and risk level
#
# By creating boxplots, I looked for outliers in suspected variables. It's important that the students in the different treatments are in the same age group for us to be able to compare them. Repeating a grade was very common in the schools we worked in and it's therefore not certain that they're all in the official 9th grade age group.
# We can see that we only have one real outlier (20 year old), but the rest is balanced.
# We can see the same over a histogram plot, showing us the mean and distribution of age over the control group and treatment 4. Comparing different treatments gives a similar histogram.
# The reported risk level tells us interestingly, that some students clame they are complete risk averse (0/10) or risk loving (10/10).
#
# 2) Correlation
#
# We can see how the different variables are correlated in a clear way by using heatmaps.
# The first heatmap looks at the correlation of variables in our summary statistics. We find that the treatment groups are correlated with higher goal achievment, which is important and the map makes sense in that number of people in the household is highly correlated with having a sibling in school. There are no significant correlation for the other variables.
# In the second heatmap, we can see the correlation between the different treatment groups. We notice that the two incentive treatments are correlated. Both of these treatments are correlated with higher mean individual goal achivement, which makes sense and shows how strong the effect of the incentive was.
#
# 3) Mean Achievement by treatment groups and gender
#
# Previous analysis in Stata had a graph of mean individual goal achievement by treatment. I included in tables and graphs gender to go more in detail to look at the effect of the different treatments. This enables us to look at mean, variance and standard deviation as well.
# We can see that the highest overall performance was in Treatment 5 (Self-help group and prize), boys and girls are doing equally good in this treatment. There is not a significant difference between Treatment 4 (No self-help group and prize) and Treatment 5, which illustrates the importance of incentives, although the coefficient is higher for Treatment 5. There is however a clear difference between boys and girls, where girls are doing significantly better in the incentive treatment. Interestingly, there is a significant difference between Treatment 2 (No self-help group and no prize) and Treatment 3 (Self-help groups and no prize). Self-help groups alone significantly increase the probability of achieving a goal. Similarly to Treatment 4, girls are performing better than boys in these two treatments. The control group is not represented because they are not selecting goals.
# The swarmplot gives a more detailed decription of this and we can see some clear differences between males and females.
#
# 4) Higher Self-esteem may lead to higher goal achievement
#
# The regplot and jointplot shows how there seem to be a positive correlation between self-esteem and individual mean goal achievement. This is interesting in that our treatments may be more effective on students with higher level of self-esteem. This might be important for the treatment effects and is potentially a nice addition to our paper and something needed to be explored further in future regressions.
#
# 5) Difficult of goals may play a role in goal achievement when combined with risk and self-esteem
#
# In the multiple tables at the end we can look at how the difficulty level a student give for their objective
# might be correlated with their self-esteem, risk level and the mean achievement of the student.
# We can see in the upper right corner, that picking goals with difficulty level 'Hard' seem to be correlated
# with stating a high risk level and achiving more goals. This is consistent with goal-setting theory.
# We see the opposite for self-esteem, where high self-esteem picks easier goals and achieve them more often.
# The histogram shows that most students found their goals to be easy and the goals are achieved regardless of their reported difficulty level.
# The residplot shows us that there is no pattern of the residuals of these variables. This is promising for future analysis.
